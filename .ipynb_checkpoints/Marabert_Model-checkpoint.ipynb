# %% [markdown]
# # Fine Tuning Arabert

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import AutoTokenizer, AutoModel, AdamW, get_linear_schedule_with_warmup
import pandas as pd
import matplotlib.pyplot as plt
import os

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('dataset.xlsx')
texts = df['content'].tolist()

# %%
tokenizer = AutoTokenizer.from_pretrained('UBC-NLP/MARBERTv2')
inputs = tokenizer(texts, padding=True, truncation=True, max_length=128, return_tensors="pt")

model = AutoModel.from_pretrained('UBC-NLP/MARBERTv2')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
inputs = {key: val.to(device) for key, val in inputs.items()}

batch_size = 64
dataset = TensorDataset(inputs['input_ids'], inputs['attention_mask'], inputs['token_type_ids'])
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

learning_rate = 2e-5
weight_decay = 0.01
optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

epochs = 300
total_steps = len(dataloader) * epochs
warmup_steps = int(0.12 * total_steps)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)

loss_values = []
early_stopping_patience = 3
best_loss = float('inf')
no_improvement_epochs = 0

for epoch in range(epochs):
    epoch_loss = 0
    model.train()

    for i, batch in enumerate(dataloader):
        batch = tuple(t.to(device) for t in batch)
        inputs = {'input_ids': batch[0], 'attention_mask': batch[1], 'token_type_ids': batch[2]}

        optimizer.zero_grad()
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state
        loss = embeddings.norm()

        loss.backward()
        optimizer.step()
        scheduler.step()

        epoch_loss += loss.item()

    avg_epoch_loss = epoch_loss / len(dataloader)
    loss_values.append(avg_epoch_loss)

    print(f"Epoch {epoch + 1}/{epochs} completed. Loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1
        if no_improvement_epochs >= early_stopping_patience:
            break

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(loss_values) + 1), loss_values)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/300 completed. Loss: 56.1997
# Epoch 2/300 completed. Loss: 56.0839
# Epoch 3/300 completed. Loss: 55.9676
# Epoch 4/300 completed. Loss: 55.8515
# Epoch 5/300 completed. Loss: 55.7351
# Epoch 6/300 completed. Loss: 55.6187
# Epoch 7/300 completed. Loss: 55.5021
# Epoch 8/300 completed. Loss: 55.3853
# Epoch 9/300 completed. Loss: 55.2684
# Epoch 10/300 completed. Loss: 55.1515
# Epoch 11/300 completed. Loss: 55.0347
# Epoch 12/300 completed. Loss: 54.9192
# Epoch 13/300 completed. Loss: 54.8049
# Epoch 14/300 completed. Loss: 54.6906
# Epoch 15/300 completed. Loss: 54.5764
# Epoch 16/300 completed. Loss: 54.4622
# Epoch 17/300 completed. Loss: 54.3485
# Epoch 18/300 completed. Loss: 54.2352
# Epoch 19/300 completed. Loss: 54.1221
# Epoch 20/300 completed. Loss: 54.0089
# Epoch 21/300 completed. Loss: 53.8958
# Epoch 22/300 completed. Loss: 53.7831
# Epoch 23/300 completed. Loss: 53.6704
# Epoch 24/300 completed. Loss: 53.5577
# Epoch 25/300 completed. Loss: 53.4449
# Epoch 26/300 completed. Loss: 53.3323
# Epoch 27/300 completed. Loss: 53.2186
# Epoch 28/300 completed. Loss: 53.1052
# Epoch 29/300 completed. Loss: 52.9919
# Epoch 30/300 completed. Loss: 52.8786
# Epoch 31/300 completed. Loss: 52.7654
# Epoch 32/300 completed. Loss: 52.6520
# Epoch 33/300 completed. Loss: 52.5380
# Epoch 34/300 completed. Loss: 52.4239
# Epoch 35/300 completed. Loss: 52.3087
# Epoch 36/300 completed. Loss: 52.1914
# Epoch 37/300 completed. Loss: 52.0735
# Epoch 38/300 completed. Loss: 51.9546
# Epoch 39/300 completed. Loss: 51.8342
# Epoch 40/300 completed. Loss: 51.7133
# Epoch 41/300 completed. Loss: 51.5929
# Epoch 42/300 completed. Loss: 51.4721
# Epoch 43/300 completed. Loss: 51.3511
# Epoch 44/300 completed. Loss: 51.2299
# Epoch 45/300 completed. Loss: 51.1086
# Epoch 46/300 completed. Loss: 50.9877
# Epoch 47/300 completed. Loss: 50.8674
# Epoch 48/300 completed. Loss: 50.7471
# Epoch 49/300 completed. Loss: 50.6266
# Epoch 50/300 completed. Loss: 50.5054
# Epoch 51/300 completed. Loss: 50.3845
# Epoch 52/300 completed. Loss: 50.2635
# Epoch 53/300 completed. Loss: 50.1424
# Epoch 54/300 completed. Loss: 50.0206
# Epoch 55/300 completed. Loss: 49.8992
# Epoch 56/300 completed. Loss: 49.7779
# Epoch 57/300 completed. Loss: 49.6565
# Epoch 58/300 completed. Loss: 49.5351
# Epoch 59/300 completed. Loss: 49.4133
# Epoch 60/300 completed. Loss: 49.2915
# Epoch 61/300 completed. Loss: 49.1697
# Epoch 62/300 completed. Loss: 49.0476
# Epoch 63/300 completed. Loss: 48.9254
# Epoch 64/300 completed. Loss: 48.8032
# Epoch 65/300 completed. Loss: 48.6811
# Epoch 66/300 completed. Loss: 48.5593
# Epoch 67/300 completed. Loss: 48.4376
# Epoch 68/300 completed. Loss: 48.3158
# Epoch 69/300 completed. Loss: 48.1940
# Epoch 70/300 completed. Loss: 48.0723
# Epoch 71/300 completed. Loss: 47.9505
# Epoch 72/300 completed. Loss: 47.8287
# Epoch 73/300 completed. Loss: 47.7070
# Epoch 74/300 completed. Loss: 47.5857
# Epoch 75/300 completed. Loss: 47.4646
# Epoch 76/300 completed. Loss: 47.3436
# Epoch 77/300 completed. Loss: 47.2225
# Epoch 78/300 completed. Loss: 47.1015
# Epoch 79/300 completed. Loss: 46.9806
# Epoch 80/300 completed. Loss: 46.8594
# Epoch 81/300 completed. Loss: 46.7380
# Epoch 82/300 completed. Loss: 46.6162
# Epoch 83/300 completed. Loss: 46.4939
# Epoch 84/300 completed. Loss: 46.3715
# Epoch 85/300 completed. Loss: 46.2489
# Epoch 86/300 completed. Loss: 46.1260
# Epoch 87/300 completed. Loss: 46.0023
# Epoch 88/300 completed. Loss: 45.8785
# Epoch 89/300 completed. Loss: 45.7545
# Epoch 90/300 completed. Loss: 45.6310
# Epoch 91/300 completed. Loss: 45.5074
# Epoch 92/300 completed. Loss: 45.2597
# Epoch 93/300 completed. Loss: 45.0119
# Epoch 94/300 completed. Loss: 44.7639
# Epoch 95/300 completed. Loss: 44.5163
# Epoch 96/300 completed. Loss: 44.2673
# Epoch 97/300 completed. Loss: 44.0169
# Epoch 98/300 completed. Loss: 43.7662
# Epoch 99/300 completed. Loss: 43.5152
# Epoch 100/300 completed. Loss: 43.2648
# Epoch 101/300 completed. Loss: 43.0120
# Epoch 102/300 completed. Loss: 42.7572
# Epoch 103/300 completed. Loss: 42.5007
# Epoch 104/300 completed. Loss: 42.2429
# Epoch 105/300 completed. Loss: 41.9843
# Epoch 106/300 completed. Loss: 41.7249
# Epoch 107/300 completed. Loss: 41.4635
# Epoch 108/300 completed. Loss: 41.2019
# Epoch 109/300 completed. Loss: 40.9394
# Epoch 110/300 completed. Loss: 40.6755
# Epoch 111/300 completed. Loss: 40.4104
# Epoch 112/300 completed. Loss: 40.1436
# Epoch 113/300 completed. Loss: 39.8755
# Epoch 114/300 completed. Loss: 39.6064
# Epoch 115/300 completed. Loss: 39.3372
# Epoch 116/300 completed. Loss: 39.0675
# Epoch 117/300 completed. Loss: 38.7969
# Epoch 118/300 completed. Loss: 38.5241
# Epoch 119/300 completed. Loss: 38.2498
# Epoch 120/300 completed. Loss: 37.9733
# Epoch 121/300 completed. Loss: 37.6935
# Epoch 122/300 completed. Loss: 37.4123
# Epoch 123/300 completed. Loss: 37.1298
# Epoch 124/300 completed. Loss: 36.8463
# Epoch 125/300 completed. Loss: 36.5618
# Epoch 126/300 completed. Loss: 36.2772
# Epoch 127/300 completed. Loss: 35.9928
# Epoch 128/300 completed. Loss: 35.7078
# Epoch 129/300 completed. Loss: 35.4216
# Epoch 130/300 completed. Loss: 35.1342
# Epoch 131/300 completed. Loss: 34.8456
# Epoch 132/300 completed. Loss: 34.5570
# Epoch 133/300 completed. Loss: 34.2677
# Epoch 134/300 completed. Loss: 33.9777
# Epoch 135/300 completed. Loss: 33.6882
# Epoch 136/300 completed. Loss: 33.3994
# Epoch 137/300 completed. Loss: 33.1102
# Epoch 138/300 completed. Loss: 32.8211
# Epoch 139/300 completed. Loss: 32.5309
# Epoch 140/300 completed. Loss: 32.2404
# Epoch 141/300 completed. Loss: 31.9498
# Epoch 142/300 completed. Loss: 31.6584
# Epoch 143/300 completed. Loss: 31.3652
# Epoch 144/300 completed. Loss: 31.0715
# Epoch 145/300 completed. Loss: 30.7764
# Epoch 146/300 completed. Loss: 30.4801
# Epoch 147/300 completed. Loss: 30.1825
# Epoch 148/300 completed. Loss: 29.8845
# Epoch 149/300 completed. Loss: 29.5862
# Epoch 150/300 completed. Loss: 29.2875
# Epoch 151/300 completed. Loss: 28.9872
# Epoch 152/300 completed. Loss: 28.5318
# Epoch 153/300 completed. Loss: 28.0744
# Epoch 154/300 completed. Loss: 27.6156
# Epoch 155/300 completed. Loss: 27.1559
# Epoch 156/300 completed. Loss: 26.6939
# Epoch 157/300 completed. Loss: 26.2292
# Epoch 158/300 completed. Loss: 25.7656
# Epoch 159/300 completed. Loss: 25.2998
# Epoch 160/300 completed. Loss: 24.8326
# Epoch 161/300 completed. Loss: 24.3648
# Epoch 162/300 completed. Loss: 23.8964
# Epoch 163/300 completed. Loss: 23.4270
# Epoch 164/300 completed. Loss: 22.9573
# Epoch 165/300 completed. Loss: 22.4886
# Epoch 166/300 completed. Loss: 22.0209
# Epoch 167/300 completed. Loss: 21.5536
# Epoch 168/300 completed. Loss: 21.0880
# Epoch 169/300 completed. Loss: 20.6236
# Epoch 170/300 completed. Loss: 20.1590
# Epoch 171/300 completed. Loss: 19.6955
# Epoch 172/300 completed. Loss: 19.2348
# Epoch 173/300 completed. Loss: 18.7756
# Epoch 174/300 completed. Loss: 18.3188
# Epoch 175/300 completed. Loss: 17.8641
# Epoch 176/300 completed. Loss: 17.4108
# Epoch 177/300 completed. Loss: 16.9608
# Epoch 178/300 completed. Loss: 16.5146
# Epoch 179/300 completed. Loss: 16.0718
# Epoch 180/300 completed. Loss: 15.6330
# Epoch 181/300 completed. Loss: 15.1969
# Epoch 182/300 completed. Loss: 14.7646
# Epoch 183/300 completed. Loss: 14.3367
# Epoch 184/300 completed. Loss: 13.9128
# Epoch 185/300 completed. Loss: 13.4936
# Epoch 186/300 completed. Loss: 13.0791
# Epoch 187/300 completed. Loss: 12.6692
# Epoch 188/300 completed. Loss: 12.2648
# Epoch 189/300 completed. Loss: 11.8662
# Epoch 190/300 completed. Loss: 11.4741
# Epoch 191/300 completed. Loss: 11.0892
# Epoch 192/300 completed. Loss: 10.7106
# Epoch 193/300 completed. Loss: 10.3390
# Epoch 194/300 completed. Loss: 9.9726
# Epoch 195/300 completed. Loss: 9.6115
# Epoch 196/300 completed. Loss: 9.2565
# Epoch 197/300 completed. Loss: 8.9086
# Epoch 198/300 completed. Loss: 8.5677
# Epoch 199/300 completed. Loss: 8.2340
# Epoch 200/300 completed. Loss: 7.9076
# Epoch 201/300 completed. Loss: 7.5886
# Epoch 202/300 completed. Loss: 7.2755
# Epoch 203/300 completed. Loss: 6.9698
# Epoch 204/300 completed. Loss: 6.6712
# Epoch 205/300 completed. Loss: 6.3793
# Epoch 206/300 completed. Loss: 6.0945
# Epoch 207/300 completed. Loss: 5.8181
# Epoch 208/300 completed. Loss: 5.5497
# Epoch 209/300 completed. Loss: 5.2892
# Epoch 210/300 completed. Loss: 5.0364
# Epoch 211/300 completed. Loss: 4.7916
# Epoch 212/300 completed. Loss: 4.5547
# Epoch 213/300 completed. Loss: 4.3259
# Epoch 214/300 completed. Loss: 4.1050
# Epoch 215/300 completed. Loss: 3.8921
# Epoch 216/300 completed. Loss: 3.6872
# Epoch 217/300 completed. Loss: 3.4899
# Epoch 218/300 completed. Loss: 3.2997
# Epoch 219/300 completed. Loss: 3.1171
# Epoch 220/300 completed. Loss: 2.9421
# Epoch 221/300 completed. Loss: 2.7741
# Epoch 222/300 completed. Loss: 2.5085
# Epoch 223/300 completed. Loss: 2.2599
# Epoch 224/300 completed. Loss: 2.0286
# Epoch 225/300 completed. Loss: 1.8139
# Epoch 226/300 completed. Loss: 1.6161
# Epoch 227/300 completed. Loss: 1.4348
# Epoch 228/300 completed. Loss: 1.2695
# Epoch 229/300 completed. Loss: 1.1198
# Epoch 230/300 completed. Loss: 0.9850
# Epoch 231/300 completed. Loss: 0.8644
# Epoch 232/300 completed. Loss: 0.7572
# Epoch 233/300 completed. Loss: 0.6626
# Epoch 234/300 completed. Loss: 0.5796
# Epoch 235/300 completed. Loss: 0.5076
# Epoch 236/300 completed. Loss: 0.4457
# Epoch 237/300 completed. Loss: 0.3930
# Epoch 238/300 completed. Loss: 0.3488
# Epoch 239/300 completed. Loss: 0.3121
# Epoch 240/300 completed. Loss: 0.2822
# Epoch 241/300 completed. Loss: 0.2581
# Epoch 242/300 completed. Loss: 0.2392
# Epoch 243/300 completed. Loss: 0.2247
# Epoch 244/300 completed. Loss: 0.2138
# Epoch 245/300 completed. Loss: 0.2060
# Epoch 246/300 completed. Loss: 0.2007
# Epoch 247/300 completed. Loss: 0.1973
# Epoch 248/300 completed. Loss: 0.1954
# Epoch 249/300 completed. Loss: 0.1945
# Epoch 250/300 completed. Loss: 0.1943
# Epoch 251/300 completed. Loss: 0.1947
# Epoch 252/300 completed. Loss: 0.1951
# Epoch 253/300 completed. Loss: 0.1955
# Epoch 254/300 completed. Loss: 0.1957
# Epoch 255/300 completed. Loss: 0.1956
# Epoch 256/300 completed. Loss: 0.1952
# Epoch 257/300 completed. Loss: 0.1941
# Epoch 258/300 completed. Loss: 0.1925
# Epoch 259/300 completed. Loss: 0.1886
# Epoch 260/300 completed. Loss: 0.1845
# Epoch 261/300 completed. Loss: 0.1808
# Epoch 262/300 completed. Loss: 0.1773
# Epoch 263/300 completed. Loss: 0.1741
# Epoch 264/300 completed. Loss: 0.1710
# Epoch 265/300 completed. Loss: 0.1680
# Epoch 266/300 completed. Loss: 0.1651
# Epoch 267/300 completed. Loss: 0.1625
# Epoch 268/300 completed. Loss: 0.1601
# Epoch 269/300 completed. Loss: 0.1579
# Epoch 270/300 completed. Loss: 0.1558
# Epoch 271/300 completed. Loss: 0.1539
# Epoch 272/300 completed. Loss: 0.1539
# Epoch 273/300 completed. Loss: 0.1539
# Epoch 274/300 completed. Loss: 0.1538
# Epoch 275/300 completed. Loss: 0.1538
# Epoch 276/300 completed. Loss: 0.1538
# Epoch 277/300 completed. Loss: 0.1537
# Epoch 278/300 completed. Loss: 0.1537
# Epoch 279/300 completed. Loss: 0.1537
# Epoch 280/300 completed. Loss: 0.1536
# Epoch 281/300 completed. Loss: 0.1536
# Epoch 282/300 completed. Loss: 0.1535
# Epoch 283/300 completed. Loss: 0.1535
# Epoch 284/300 completed. Loss: 0.1535
# Epoch 285/300 completed. Loss: 0.1534
# Epoch 286/300 completed. Loss: 0.1534
# Epoch 287/300 completed. Loss: 0.1534
# Epoch 288/300 completed. Loss: 0.1533
# Epoch 289/300 completed. Loss: 0.1533
# Epoch 290/300 completed. Loss: 0.1532
# Epoch 291/300 completed. Loss: 0.1532
# Epoch 292/300 completed. Loss: 0.1532
# Epoch 293/300 completed. Loss: 0.1531
# Epoch 294/300 completed. Loss: 0.1531
# Epoch 295/300 completed. Loss: 0.1531
# Epoch 296/300 completed. Loss: 0.1530
# Epoch 297/300 completed. Loss: 0.1530
# Epoch 298/300 completed. Loss: 0.1530
# Epoch 299/300 completed. Loss: 0.1529
# Epoch 300/300 completed. Loss: 0.1529
