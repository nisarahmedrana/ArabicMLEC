# %% [markdown]
# # Fine Tuning Arabert

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import AutoTokenizer, AutoModel, AdamW, get_linear_schedule_with_warmup
import pandas as pd
import matplotlib.pyplot as plt
import os

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('dataset.xlsx')
texts = df['content'].tolist()

# %%
tokenizer = AutoTokenizer.from_pretrained('aubmindlab/bert-base-arabertv02')
inputs = tokenizer(texts, padding=True, truncation=True, max_length=128, return_tensors="pt")

model = AutoModel.from_pretrained('aubmindlab/bert-base-arabertv02')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
inputs = {key: val.to(device) for key, val in inputs.items()}

batch_size = 32
dataset = TensorDataset(inputs['input_ids'], inputs['attention_mask'], inputs['token_type_ids'])
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

learning_rate = 2e-4
weight_decay = 0.001
optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

epochs = 300
total_steps = len(dataloader) * epochs
warmup_steps = int(0.13 * total_steps)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)

loss_values = []
early_stopping_patience = 3
best_loss = float('inf')
no_improvement_epochs = 0

for epoch in range(epochs):
    epoch_loss = 0
    model.train()

    for i, batch in enumerate(dataloader):
        batch = tuple(t.to(device) for t in batch)
        inputs = {'input_ids': batch[0], 'attention_mask': batch[1], 'token_type_ids': batch[2]}

        optimizer.zero_grad()
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state
        loss = embeddings.norm()

        loss.backward()
        optimizer.step()
        scheduler.step()

        epoch_loss += loss.item()

    avg_epoch_loss = epoch_loss / len(dataloader)
    loss_values.append(avg_epoch_loss)

    print(f"Epoch {epoch + 1}/{epochs} completed. Loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1
        if no_improvement_epochs >= early_stopping_patience:
            break

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(loss_values) + 1), loss_values)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/300 completed. Loss: 59.5440
# Epoch 2/300 completed. Loss: 59.4378
# Epoch 3/300 completed. Loss: 59.3323
# Epoch 4/300 completed. Loss: 59.2281
# Epoch 5/300 completed. Loss: 59.1242
# Epoch 6/300 completed. Loss: 59.0200
# Epoch 7/300 completed. Loss: 58.9158
# Epoch 8/300 completed. Loss: 58.8114
# Epoch 9/300 completed. Loss: 58.7077
# Epoch 10/300 completed. Loss: 58.6061
# Epoch 11/300 completed. Loss: 58.5055
# Epoch 12/300 completed. Loss: 58.4054
# Epoch 13/300 completed. Loss: 58.3063
# Epoch 14/300 completed. Loss: 58.2074
# Epoch 15/300 completed. Loss: 58.1086
# Epoch 16/300 completed. Loss: 58.0101
# Epoch 17/300 completed. Loss: 57.9116
# Epoch 18/300 completed. Loss: 57.8133
# Epoch 19/300 completed. Loss: 57.7153
# Epoch 20/300 completed. Loss: 57.6175
# Epoch 21/300 completed. Loss: 57.5197
# Epoch 22/300 completed. Loss: 57.4220
# Epoch 23/300 completed. Loss: 57.3249
# Epoch 24/300 completed. Loss: 57.2288
# Epoch 25/300 completed. Loss: 57.1328
# Epoch 26/300 completed. Loss: 57.0375
# Epoch 27/300 completed. Loss: 56.9428
# Epoch 28/300 completed. Loss: 56.8484
# Epoch 29/300 completed. Loss: 56.7542
